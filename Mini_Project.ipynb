# %% [markdown]
# <a href="https://colab.research.google.com/github/8dci/mini_project/blob/main/Mini_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/Traffic Accident Statistics as of 1439 H.CSV')
df
# Out:
#          الشهر  حادث تلفيات  حادث اصابات  حادث وفيات   مجموع عدد الحوادث  \
# 0         محرم       5047.0        277.0        75.0              5399.0
# 1          صفر       5941.0        255.0        78.0              6274.0
# 2     ربيع أول       7808.0        271.0        87.0              8166.0
# 3    ربيع ثانى       7821.0        266.0        79.0              8166.0
# 4    جمادى أول       7923.0        237.0        81.0              8241.0
# 5   جمادى ثانى       6449.0        259.0        79.0              6787.0
# 6          رجب       6955.0        227.0        65.0              7247.0
# 7        شعبان       6516.0        258.0        63.0              6837.0
# 8        رمضان       4997.0        229.0        71.0              5297.0
# 9         شوال       5226.0        238.0        80.0              5544.0
# 10   ذى القعدة       5620.0        197.0        54.0              5871.0
# 11    ذى الحجة       5786.0        183.0        86.0              6055.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 74 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   الشهر                                              13 non-null     object
#  1   حادث تلفيات                                        13 non-null     float64
#  2   حادث اصابات                                        13 non-null     float64
#  3   حادث وفيات                                         13 non-null     float64
#  4    مجموع عدد الحوادث                                 13 non-null     float64
#  5   السبت                                              13 non-null     float64
#  6   الا حد                                             13 non-null     float64
#  7   الاثنين                                            13 non-null     float64
# ...

# %%
df.isna().sum()
# Out:
# الشهر                               0
# حادث تلفيات                         0
# حادث اصابات                         0
# حادث وفيات                          0
#  مجموع عدد الحوادث                  0
#                                    ..
# مجموع الحوادث حسب سبب الحادث        0
# عدد المصابين                        0
# عدد المتوفين (القتلى)               0
# سليم                                0
# مجموع الأشخاص المشمولين بالحوادث    0
# Length: 74, dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0
